# %%
# !pip install autoscraper

from autoscraper import AutoScraper
import pandas as pd
# Out:
# Requirement already satisfied: autoscraper in /usr/local/lib/python3.10/dist-packages (1.1.14)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from autoscraper) (2.31.0)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.10/dist-packages (from autoscraper) (0.0.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from autoscraper) (4.9.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4->autoscraper) (4.11.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->autoscraper) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->autoscraper) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->autoscraper) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->autoscraper) (2023.7.22)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4->autoscraper) (2.5)

# %%
search = "iphone"
amazon_url="https://www.amazon.in/s?k={}".format(search)
print(amazon_url)
# Out:
# https://www.amazon.in/s?k=iphone

# %%
wanted_list=["https://m.media-amazon.com/images/I/61cwywLZR-L._AC_UY218_.jpg","Apple iPhone 14 (128 GB) - Midnight","699","3625"]

# %%
scraper=AutoScraper()
result=scraper.build(amazon_url,wanted_list)

# %%
data = scraper.get_result_similar(amazon_url,grouped=True)
print(data)
# Out:
# {'rule_fpi5': ['https://m.media-amazon.com/images/I/61VuVU94RnL._AC_UY218_.jpg', 'https://m.media-amazon.com/images/I/61-r9zOKBCL._AC_UY218_.jpg', 'https://m.media-amazon.com/images/I/71GLMJ7TQiL._AC_UY218_.jpg', 'https://m.media-amazon.com/images/I/71QE00iB9IL._AC_UY218_.jpg', 'https://m.media-amazon.com/images/I/61cwywLZR-L._AC_UY218_.jpg', 'https://m.media-amazon.com/images/I/61bK6PMOC3L._AC_UY218_.jpg', 'https://m.media-amazon.com/images/I/618Bb+QzCmL._AC_UY218_.jpg', 'https://m.media-amazon.com/images/I/71T5NVOgbpL._AC_UY218_.jpg', 'https://m.media-amazon.com/images/I/71ZDY57yTQL._AC_UY218_.jpg', 'https://m.media-amazon.com/images/I/61B0+qQriPL._AC_UY218_.jpg', 'https://m.media-amazon.com/images/I/61bK6PMOC3L._AC_UY218_.jpg', 'https://m.media-amazon.com/images/I/61BGE6iu4AL._AC_UY218_.jpg', 'https://m.media-amazon.com/images/I/61YSNhAb00L._AC_UY218_.jpg', 'https://m.media-amazon.com/images/I/61cwywLZR-L._AC_UY218_.jpg', 'https://m.media-amazon.com/images/I/611mRs-imxL._AC_UY218_.jpg', 'https://m.media-amazon.com/images/I/619f09kK7tL._AC_UY218_.jpg'], 'rule_87ns': ['https://m.media-amazon.com/images/I/61VuVU94RnL._AC_UY218_.jpg', 'https://m.media-amazon.com/images/I/61-r9zOKBCL._AC_UY218_.jpg', 'https://m.media-amazon.com/images/I/71GLMJ7TQiL._AC_UY218_.jpg', 'https://m.media-amazon.com/images/I/71QE00iB9IL._AC_UY218_.jpg', 'https://m.media-amazon.com/images/I/61cwywLZR-L._AC_UY218_.jpg', 'https://m.media-amazon.com/images/I/61bK6PMOC3L._AC_UY218_.jpg', 'https://m.media-amazon.com/images/I/618Bb+QzCmL._AC_UY218_.jpg', 'https://m.media-amazon.com/images/I/71T5NVOgbpL._AC_UY218_.jpg', 'https://m.media-amazon.com/images/I/71ZDY57yTQL._AC_UY218_.jpg', 'https://m.media-amazon.com/images/I/61B0+qQriPL._AC_UY218_.jpg', 'https://m.media-amazon.com/images/I/61bK6PMOC3L._AC_UY218_.jpg', 'https://m.media-amazon.com/images/I/61BGE6iu4AL._AC_UY218_.jpg', 'https://m.media-amazon.com/images/I/61YSNhAb00L._AC_UY218_.jpg', 'https://m.media-amazon.com/images/I/61cwywLZR-L._AC_UY218_.jpg', 'https://m.media-amazon.com/images/I/611mRs-imxL._AC_UY218_.jpg', 'https://m.media-amazon.com/images/I/619f09kK7tL._AC_UY218_.jpg'], 'rule_i9zt': ['Apple iPhone 13 (128GB) - Midnight  Suitable for PhotographyThis phone is suitable for photography based on product specifications.Learn more', 'Apple iPhone 13 (128GB) - Green  Suitable for PhotographyThis phone is suitable for photography based on product specifications.Learn more', 'Apple iPhone 13 (128GB) - Starlight  Suitable for PhotographyThis phone is suitable for photography based on product specifications.Learn more', 'Apple iPhone 11 (64GB) - White  Suitable for PhotographyThis phone is suitable for photography based on product specifications.Learn more', 'Apple iPhone 14 (128 GB) - Midnight  Suitable for PhotographyThis phone is suitable for photography based on product specifications.Learn more', 'Apple iPhone 14 (128 GB) - Blue  Suitable for PhotographyThis phone is suitable for photography based on product specifications.Learn more', 'Apple iPhone 14 (128 GB) - Starlight  Suitable for PhotographyThis phone is suitable for photography based on product specifications.Learn more', 'Apple iPhone 14 Pro Max (256 GB) - Gold  Suitable for PhotographyThis phone is suitable for photography based on product specifications.Learn more', 'Apple iPhone 14 Pro (128 GB) - Gold  Suitable for PhotographyThis phone is suitable for photography based on product specifications.Learn more', 'Apple iPhone 14 Plus (128 GB) - Midnight  Suitable for PhotographyThis phone is suitable for photography based on product specifications.Learn more', 'Apple iPhone 14 (256 GB) - Blue  Suitable for PhotographyThis phone is suitable for photography based on product specifications.Learn more', 'Apple iPhone 14 Plus (128 GB) - Blue  Suitable for PhotographyThis phone is suitable for photography based on product specifications.Learn more', 'Apple iPhone 14 Plus (128 GB) - Purple  Suitable for EntertainmentThis phone is suitable for ente ...

# %%
keys = list(data.keys())
print(keys)
# Out:
# ['rule_fpi5', 'rule_87ns', 'rule_i9zt', 'rule_gjy2']

# %%
scraper.set_rule_aliases({str(keys[0]):'ImageUrl',str(keys[1]):'Title',str(keys[-2]):'Price',str(keys[-1]):'Reviews'})
scraper.save("amazon_in.json")

# %%
amazon_scraper = AutoScraper()
amazon_scraper.load('amazon_in.json')

search = "samsung phones"
amazon_url="https://www.amazon.in/s?k={}".format(search)

data = amazon_scraper.get_result_similar(amazon_url, group_by_alias=True)
search_data = tuple(zip(data['Title'],data['ImageUrl'],data['Price'],data['Reviews']))

df = pd.DataFrame(columns=['Query','Title','Price','Reviews','ImageUrl'])
for i in range(len(search_data)):
    df.loc[len(df)] = [search,search_data[i][0],search_data[i][2],search_data[i][3],search_data[i][1]]

# %%
print(df.shape)
df
# Out:
# (16, 5)
#              Query                                              Title  \
# 0   samsung phones  https://m.media-amazon.com/images/I/81-fFXQdPT...
# 1   samsung phones  https://m.media-amazon.com/images/I/81Prc5i7hM...
# 2   samsung phones  https://m.media-amazon.com/images/I/81Prc5i7hM...
# 3   samsung phones  https://m.media-amazon.com/images/I/91ItZJh1FD...
# 4   samsung phones  https://m.media-amazon.com/images/I/81EtFZ6GA1...
# 5   samsung phones  https://m.media-amazon.com/images/I/81t6Av5DvX...
# 6   samsung phones  https://m.media-amazon.com/images/I/81t6Av5DvX...
# 7   samsung phones  https://m.media-amazon.com/images/I/812YsUxpyf...
# 8   samsung phones  https://m.media-amazon.com/images/I/71kfHC4ANJ...
# 9   samsung phones  https://m.media-amazon.com/images/I/81-fFXQdPT...
# 10  samsung phones  https://m.media-amazon.com/images/I/71f2I8cltB...
# 11  samsung phones  https://m.media-amazon.com/images/I/818VqDSKpC...
# 12  samsung phones  https://m.media-amazon.com/images/I/818VqDSKpC...
# 13  samsung phones  https://m.media-amazon.com/images/I/814ePfNubR...
# 14  samsung phones  https://m.media-amazon.com/images/I/812YsUxpyf...
# 15  samsung phones  https://m.media-amazon.com/images/I/61RZDb2mQx...
#
#                                                 Price  \
# 0   Samsung Galaxy M13 (Aqua Green, 4GB, 64GB Stor...
# 1   Samsung Galaxy M13 (Stardust Brown, 6GB, 128GB...
# 2   Samsung Galaxy M13 (Stardust Brown, 4GB, 64GB ...
# 3   Samsung Galaxy M34 5G (Prism Silver, 8GB, 128G...
# 4   Samsung Galaxy A23 5G, Light Blue (8GB, 128GB ...
# 5   Samsung Galaxy M04 Dark Blue, 4GB RAM, 128GB S...
# 6   Samsung Galaxy M04 Dark Blue, 4GB RAM, 64GB St...
# 7                 Amazon's Choicefor "samsung phones"
# 8   Samsung Galaxy M13 (Midnight Blue, 6GB, 128GB ...
# 9   Samsung Galaxy A54 5G (Awesome Violet, 8GB, 25...
# 10  Samsung Galaxy M13 (Aqua Green, 6GB, 128GB Sto...
# 11  Samsung Galaxy Z Flip3 5G (Cream, 8GB RAM, 128...
# 12  Samsung Galaxy M14 5G (Smoky Teal, 6GB, 128GB ...
# 13  Samsung Galaxy M14 5G (Smoky Teal, 4GB, 128GB ...
# 14  Samsung Galaxy M04 Light Green, 4GB RAM, 128GB...
# 15  Samsung Galaxy M13 (Midnight Blue, 4GB, 64GB S...
#
#                                               Reviews  \
# 0   Samsung Galaxy M13 (Aqua Green, 4GB, 64GB Stor...
# 1   Samsung Galaxy M13 (Stardust Brown, 6GB, 128GB...
# 2   Samsung Galaxy M13 (Stardust Brown, 4GB, 64GB ...
# 3   Samsung Galaxy M34 5G (Prism Silver, 8GB, 128G...
# 4   Samsung Galaxy A23 5G, Light Blue (8GB, 128GB ...
# 5   Samsung Galaxy M04 Dark Blue, 4GB RAM, 128GB S...
# 6   Samsung Galaxy M04 Dark Blue, 4GB RAM, 64GB St...
# 7   Samsung Galaxy M13 (Midnight Blue, 6GB, 128GB ...
# 8   Samsung Galaxy A54 5G (Awesome Violet, 8GB, 25...
# 9   Samsung Galaxy M13 (Aqua Green, 6GB, 128GB Sto...
# 10  Samsung Galaxy Z Flip3 5G (Cream, 8GB RAM, 128...
# 11  Samsung Galaxy M14 5G (Smoky Teal, 6GB, 128GB ...
# 12  Samsung Galaxy M14 5G (Smoky Teal, 4GB, 128GB ...
# 13  Samsung Galaxy M04 Light Green, 4GB RAM, 128GB...
# 14  Samsung Galaxy M13 (Midnight Blue, 4GB, 64GB S...
# 15  Samsung Galaxy S23 5G (Green, 8GB, 256GB Storage)
#
#                                              ImageUrl
# 0   https://m.media-amazon.com/images/I/81-fFXQdPT...
# 1   https://m.media-amazon.com/images/I/81Prc5i7hM...
# 2   https://m.media-amazon.com/images/I/81Prc5i7hM...
# 3   https://m.media-amazon.com/images/I/91ItZJh1FD...
# 4   https://m.media-amazon.com/images/I/81EtFZ6GA1...
# 5   https://m.media-amazon.com/images/I/81t6Av5DvX...
# 6   https://m.media-amazon.com/images/I/81t6Av5DvX...
# 7   https://m.media-amazon.com/images/I/812YsUxpyf...
# 8   https://m.media-amazon.com/images/I/71kfHC4ANJ...
# 9   https://m.media-amazon.com/images/I/81-fFXQdPT...
# 10  https://m.media-amazon.com/images/I/71f2I8cltB...
# 11  https://m.media-amazon.com/images/I/818VqDSKpC...
# 12  https://m.media-amazon.com/images/I/818VqDSKpC...
# 13  https://m.media-amazon.com/images/I/814ePfNubR...
# 14  https://m.media-amazon.com/images/I/812YsUxpyf...
# 15  https://m.media-amazon.com/images/I/61RZDb2mQx...
